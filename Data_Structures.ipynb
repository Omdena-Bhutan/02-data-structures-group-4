# %% [markdown]
# <a href="https://colab.research.google.com/github/Omdena-Bhutan/02-data-structures-group-4/blob/main/Data_Structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# List

# %%
# defining a List
my_list = [1,2,3,4]

# %%
# how to know the data strcuture
type(my_list)
# Out:
# list

# %%
# a list of names
names = ['karma', 'sangay', 'pradeep', 'pema']

# %%
print(names)
# Out:
# ['karma', 'sangay', 'pradeep', 'pema']

# %%
# Mixed list
mixed_list = ['karma', 123, 1, 4, 5, ['sangay,', 990, 2, 3, 5]]

# %%
print(mixed_list)
# Out:
# ['karma', 123, 1, 4, 5, ['sangay,', 990, 2, 3, 5]]

# %% [markdown]
# Operations in List

# %%
# Adding elements into a list
names.append('chetan')

# %%
print(names)
# Out:
# ['karma', 'sangay', 'pradeep', 'pema', 'chetan']

# %%
# Removing an element
names.remove('sangay')

# %%
print(names)
# Out:
# ['karma', 'pradeep', 'pema', 'chetan']

# %%
names[1]
# Out:
# 'pradeep'

# %% [markdown]
# TUBLES
# -Ordered, immutable collections of elements in python

# %%
my_tuple = (1, 2, 3)

# %%
print(my_tuple)
# Out:
# (1, 2, 3)

# %%
my_tuple[1]
# Out:
# 2

# %% [markdown]
# **Dictionaries**
# - is a data structure that stores key values pair.
# ---key have to be unique, immutable

# %%
my_dict ={'name':'Karma', 'age': 25,'job': 'ML Engineer', 'city':'new york'}

# %%
print(my_dict)
# Out:
# {'name': 'Karma', 'age': 25, 'job': 'ML Engineer', 'city': 'new york'}

# %%
print(my_dict['city'])
# Out:
# new york

# %%
# Another dictionary
student = {'name':"Sonam", "age":21,'major':"Mathematics"}
student
# Out:
# {'name': 'Sonam', 'age': 21, 'major': 'Mathematics'}

# %%
# Updating an existing element
student['age'] = 26
student
# Out:
# {'name': 'Sonam', 'age': 26, 'major': 'Mathematics', 'student': 26}

# %%
student = {'name': 'Sonam', 'age': 21, 'major': 'Mathematics'}
student['age'] = 26
print(student)
# Out:
# {'name': 'Sonam', 'age': 26, 'major': 'Mathematics'}

# %% [markdown]
# #Sets
# -These are unordered, mutable collection of unique elements

# %%
my_set ={1, 2, 3}

# %%
my_set
# Out:
# {1, 2, 3}

# %%
# Adding elements
my_set.add(4)
my_set
# Out:
# {1, 2, 3, 4}

# %%
# Remove elements
my_set.remove(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_5299/830037359.py in <cell line: 0>()
#       1 # Remove elements
# ----> 2 my_set.remove(3)
#       3 my_set
#
# KeyError: 3

# %%
my_set
# Out:
# {1, 2, 4}
